# %%
print("hello kanhaiya")
# Out:
# hello kanhaiya

# %%
## Basics Syntax of python 
## Case sensitive-Python is case sensitive 

name = "kanhaiya"
Name = "kumar"
print(name)
print(Name)
# Out:
# kanhaiya
# kumar

# %%
#indentation 
## Python uses the indentation to define blocks of code. Consistent use of spaces or tab is requires 

ages = 32 
if ages >30:
    print(ages)

print(ages)
# Out:
# 32
# 32

# %%
## single line comment this line will not print in the statement 
print("Hii i am kanhaiya kumar and i am software developer")
# Out:
# Hii i am kanhaiya kumar and i am software developer

# %%
## Line continuation 
## use the backslash(\) to continue to the next line 
total = 1+2+3+4+5+6+7+\
4+5+6
print(total)
# Out:
# 43

# %%
##Multiple Statements on a single line 
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
#Semantics in python 
# Variable assignment 
age = 32 ## age is an integer 
name = "Kanhaiya kumar" ## name is a string 
print(type(age))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Type inference 
variable = 10
print(type(variable))
variable = "kanhaiya"
print(type(variable))
## During the runtime we can change the type of variables
# Out:
# <class 'int'>
# <class 'str'>

# %%
##name error 
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 ##name error
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation 
if True:
    print("Correct indentation")
    if False:
        print("this will not print")
    print("This will print")
print("Outside of the if block")
# Out:
# Correct indentation
# This will print
# Outside of the if block
